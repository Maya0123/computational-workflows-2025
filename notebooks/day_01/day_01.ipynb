# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# nf-core is a community effort - a diverse project where many groups collaborate to collect, develop and maintain a curated set of analysis pipelines using the powerful workflow manager nextflow.

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
#  There are 139 pipelines currently available as part of nf-core.

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?

# %% [markdown]
# Primarily it is used for bioinformatics, but yes there are.

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# A pipeline is a workflow designed to automate processes so that they are always consistent and easily reproducable. It consists of a series of defined logical steps through which data is passed from one step to anthe next according to a set of rules. One major advantage of using pipelines is that it makes working with large amounts of data easier and more efficient.

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# I would think it is important that when many people work together in a community using developing, using and maintaining pipelines, that strict guidelines are needed to prevent chaos and provide consistency.

# %% [markdown]
# 6. What are the main features of nf-core pipelines?

# %% [markdown]
# Documentation, Stable Releases, Open source, Continuous Integration Testing, Run anywhere, Packaged software
#
#
# (consistensy, repdoducability)

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes

# %% [markdown]
# nf-core/differentialabundance
#
# (Differential abundance analysis for feature/ observation matrices from platforms such as RNA-seq)

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd



# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!
# Out:
# /mnt/c/Users/Mayal/Documents/Uni Tübingen/3. Semester/Practical - Computational workflows/computational-workflows-2025/notebooks/day_01

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)


# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [intergalactic_baekeland] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : intergalactic_baekeland
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
# ...

# %% [markdown]
# Time needed for first run: 6m 32s

# %%
# repeat the run. What did change?
# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [jolly_heyrovsky] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : jolly_heyrovsky
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
# ...

# %% [markdown]
# Time needed for repeated run: 2m 48s
#
# Changes: the left side table hashes where different for the second run and it was much faster.

# %%
# now set -resume to the command. What did change?
# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [gloomy_church] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : gloomy_church
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
# ...

# %% [markdown]
# Time needed for run with -resume: 31s

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %% [markdown]
# The difference when running with -resume is that it checks for every step whether is was already done, and if so then the step gets skipped. Here for example mostly it says only cached and the hashes did not change.

# %%
# delete the work directory and run the pipeline again using -resume. What did change?

# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [voluminous_payne] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : voluminous_payne
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
# ...

# %% [markdown]
# What changed?
#
# Needed time: 3m 26s
#
# The hashes are different again, because -resume cannot reuse any previous results anymore since the work directory is removed. Therefore it is runned entirely new again and also taking more time again.

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?

# %% [markdown]
# Differential abundance analysis has the aim to indentify differences in the abundance of each taxon between two classes of subjects or samples, and assigns a significance value to each comparison (Cappellato, M., Baruzzo, G., & Di Camillo, B. (2022). Investigating differential abundance methods in microbiome data: A benchmark study. PLoS Computational Biology, 18(9), e1010467).
# It assists in finding highly confident microbial candidates for further biological validation (Yang, L., Chen, J. A comprehensive evaluation of microbial differential abundance analysis methods: current status and potential solutions. Microbiome 10, 130 (2022)).
#
#
# The pipeline to do this includes several steps that are found on the nf-core website:
#
#     - Optionally generate a list of genomic feature annotations using the input GTF file (if a table is not explicitly supplied).
#     - Cross-check matrices, sample annotations, feature set and contrasts to ensure consistency.
#     - Run differential analysis over all contrasts specified.
#     - Optionally run a differential gene set analysis.
#     - Generate exploratory and differential analysis plots for interpretation.
#     - Optionally build and (if specified) deploy a Shiny app for fully interactive mining of results.
#     - Build an HTML report based on R markdown, with interactive plots (where possible) and tables.

# %% [markdown]
# Give the most important plots from the report:

# %% [markdown]
# #### The following two plots are part of the explorative analysis:

# %%
from IPython.display import Image, display
display(Image(filename='/mnt/c/Users/Mayal/Documents/Uni Tübingen/3. Semester/Practical - Computational workflows/computational-workflows-2025/notebooks/day_01/test/boxplots_differentialAbundance.png'))

# %% [markdown]
# The boxplots show the abundance value distributions of input matrices (matrix of 1000 genes for 6 samples, reduced to 982 genes after filtering for low abundance). A log2 transformation is applied where not already performed.

# %%
from IPython.display import Image, display
display(Image(filename='/mnt/c/Users/Mayal/Documents/Uni Tübingen/3. Semester/Practical - Computational workflows/computational-workflows-2025/notebooks/day_01/test/clustering_differentialAbundance.png'))

# %% [markdown]
# A hierarchical clustering of genes was undertaken based on the 500 most variable genes. Distances between genes were estimated based on spearman correlation, which were then used to produce a clustering via the ward.D2 method with hclust() in R.

# %%
from IPython.display import Image, display
display(Image(filename='/mnt/c/Users/Mayal/Documents/Uni Tübingen/3. Semester/Practical - Computational workflows/computational-workflows-2025/notebooks/day_01/test/differentialStatus_differentialAbundance.png'))

# %% [markdown]
# This plot is part of the differential analysis showing hND6 versus mCherry in treatment (blocking: sample_number) (with adjusted p-values).
